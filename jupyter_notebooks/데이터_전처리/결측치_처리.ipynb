# %%
import pandas as pd

# %%
df = pd.read_csv("../../extra_data/merge_needed/processed/주요국제금리(월별_2023.01~2025.03).csv")
df
# Out:
#    코드(구분코드)  구분코드 코드(계정항목)       계정항목 단위   변환  2023/01  2023/02  2023/03  \
# 0      IRLT  장기금리      KOR         한국  %  원자료     3.41     3.45     3.45
# 1      IRLT  장기금리      USA         미국  %  원자료     3.53     3.75     3.66
# 2      IRLT  장기금리      CHN         중국  %  원자료     2.90     2.90     2.85
# 3      IRLT  장기금리      JPN         일본  %  원자료     0.49     0.50     0.32
# 4      IRLT  장기금리      DEU         독일  %  원자료     2.19     2.37     2.38
# 5      IRLT  장기금리      IND         인도  %  원자료     7.39     7.33     7.36
# 6      IRLT  장기금리      GBR         영국  %  원자료     3.51     3.56     3.56
# 7      IRLT  장기금리      FRA        프랑스  %  원자료     2.69     2.87     2.92
# 8      IRLT  장기금리      CAN        캐나다  %  원자료     2.94     3.17     2.99
# 9      IRLT  장기금리      ITA       이탈리아  %  원자료     4.24     4.27     4.24
# 10     IRLT  장기금리      BRA        브라질  %  원자료     7.37     7.37     7.37
# 11     IRLT  장기금리      AUS    오스트레일리아  %  원자료     3.60     3.70     3.47
# ...

# %%
target = ['한국', '호주', '칠레', '중국', '아이슬란드', '인도네시아', '일본', '룩셈부르크', '멕시코', '뉴질랜드', '']


# 3. 보간 적용 (월별 수치 열만)
value_columns = df.columns[6:]  # 앞의 메타데이터 열 제외
df[value_columns] = df[value_columns].interpolate(axis=1, limit_direction='both').round(2)

df
# Out:
#    코드(구분코드)  구분코드 코드(계정항목)       계정항목 단위   변환  2023/01  2023/02  2023/03  \
# 0      IRLT  장기금리      KOR         한국  %  원자료     3.41     3.45     3.45
# 1      IRLT  장기금리      USA         미국  %  원자료     3.53     3.75     3.66
# 2      IRLT  장기금리      CHN         중국  %  원자료     2.90     2.90     2.85
# 3      IRLT  장기금리      JPN         일본  %  원자료     0.49     0.50     0.32
# 4      IRLT  장기금리      DEU         독일  %  원자료     2.19     2.37     2.38
# 5      IRLT  장기금리      IND         인도  %  원자료     7.39     7.33     7.36
# 6      IRLT  장기금리      GBR         영국  %  원자료     3.51     3.56     3.56
# 7      IRLT  장기금리      FRA        프랑스  %  원자료     2.69     2.87     2.92
# 8      IRLT  장기금리      CAN        캐나다  %  원자료     2.94     3.17     2.99
# 9      IRLT  장기금리      ITA       이탈리아  %  원자료     4.24     4.27     4.24
# 10     IRLT  장기금리      BRA        브라질  %  원자료     7.37     7.37     7.37
# 11     IRLT  장기금리      AUS    오스트레일리아  %  원자료     3.60     3.70     3.47
# ...

# %%
df
# Out:
#    코드(구분코드)  구분코드 코드(계정항목)       계정항목 단위   변환  2023/01  2023/02  2023/03  \
# 0      IRLT  장기금리      KOR         한국  %  원자료     3.41     3.45     3.45
# 1      IRLT  장기금리      USA         미국  %  원자료     3.53     3.75     3.66
# 2      IRLT  장기금리      CHN         중국  %  원자료     2.90     2.90     2.85
# 3      IRLT  장기금리      JPN         일본  %  원자료     0.49     0.50     0.32
# 4      IRLT  장기금리      DEU         독일  %  원자료     2.19     2.37     2.38
# 5      IRLT  장기금리      IND         인도  %  원자료     7.39     7.33     7.36
# 6      IRLT  장기금리      GBR         영국  %  원자료     3.51     3.56     3.56
# 7      IRLT  장기금리      FRA        프랑스  %  원자료     2.69     2.87     2.92
# 8      IRLT  장기금리      CAN        캐나다  %  원자료     2.94     3.17     2.99
# 9      IRLT  장기금리      ITA       이탈리아  %  원자료     4.24     4.27     4.24
# 10     IRLT  장기금리      BRA        브라질  %  원자료     7.37     7.37     7.37
# 11     IRLT  장기금리      AUS    오스트레일리아  %  원자료     3.60     3.70     3.47
# ...

# %%
df.to_csv("../../extra_data/merge_needed/processed/주요국제금리(월별_2023.01~2025.03).csv", index=False)
