# %%
import pandas as pd, numpy as np

# %%
df = pd.read_csv("../../data/processed/현대_해외현지판매_전처리.csv")

# %%
df
# Out:
#                      차종          공장명(국가)   월 Korea  U.S.A Canada Mexico  \
# 0     Morning / Picanto     Korean Plant  1월     0    0.0    0.0    0.0
# 1           Pride / Rio     Korean Plant  1월     0    0.0    0.0    0.0
# 2                    K3     Korean Plant  1월     0    0.0   95.0   57.0
# 3           K5 / Optima     Korean Plant  1월     0    0.0    0.0    0.0
# 4               Stinger     Korean Plant  1월     0  466.0   22.0   10.0
# ...                 ...              ...  ..   ...    ...    ...    ...
# 1923                  0  Special Vehicle  1월     0      0      0      0
# 1924                  0  Special Vehicle  1월     0      0      0      0
# 1925                  0  Special Vehicle  1월     0      0      0      0
# 1926                  0  Special Vehicle  1월     0      0      0      0
# 1927                  0  Special Vehicle  1월     0      0      0      0
#
#       Europe Eastern Europe Latin America Middle East  Africa Asia Pacific  \
# ...

# %%
df["차종"] = df["차종"].str.strip()

# %%
df
# Out:
#            차종  차량 구분 거래 유형      1월      2월      3월      4월      5월      6월  \
# 0     Morning  일반 차량    국내  1813.0  2049.0  2127.0  2164.0  2502.0  2245.0
# 1         Ray  일반 차량    국내  3585.0  4268.0  4155.0  4158.0  4576.0  4372.0
# 2          K3  일반 차량    국내   950.0  1024.0  1197.0   670.0   975.0  1540.0
# 3          K5  일반 차량    국내  2560.0  2653.0  3421.0  2739.0  3166.0  2963.0
# 4     Stinger  일반 차량    국내   113.0   120.0   143.0    61.0    45.0     1.0
# ..        ...    ...   ...     ...     ...     ...     ...     ...     ...
# 142       PV5  일반 차량    수출       0       0       0       0       0       0
# 143    Tasman  특수 차량    수출       0       0       0       0       0       0
# 144  Military  특수 차량    수출       0       0       0       0       0       0
# 145     Bongo  특수 차량    수출      17       0       0       0       0       0
# 146       Bus  특수 차량    수출       0       0       0       0       0       0
#
#          7월      8월      9월     10월     11월     12월    연도
# ...

# %%
df.to_csv("../../data/processed/기아_차종별판매실적_전처리.csv", index=False)
