# %%
import pandas as pd

# %%
df = pd.read_csv("data/processed/기아_해외판매_전처리.csv")
df
# Out:
#        차량 구분    연도    월  수출량           차종 거래 유형  판매량       공장명(국가) 공장 코드  \
# 0      일반 차량  2023  10월  0.0  Accent (HC)    내수  0.0  Mexico Plant   KMX
# 1      일반 차량  2023  11월  0.0  Accent (HC)    내수  0.0  Mexico Plant   KMX
# 2      일반 차량  2023  12월  0.0  Accent (HC)    내수  0.0  Mexico Plant   KMX
# 3      일반 차량  2023   1월  0.0  Accent (HC)    내수  0.0  Mexico Plant   KMX
# 4      일반 차량  2023   2월  0.0  Accent (HC)    내수  0.0  Mexico Plant   KMX
# ...      ...   ...  ...  ...          ...   ...  ...           ...   ...
# 40699  일반 차량  2025   9월  0.0       Zhipao    내수  0.0  China Plants   DYK
# 40700  일반 차량  2025   9월  0.0       Zhipao    내수  0.0  China Plants   DYK
# 40701  일반 차량  2025   9월  0.0       Zhipao    내수  0.0  China Plants   DYK
# 40702  일반 차량  2025   9월  0.0       Zhipao    내수  0.0  China Plants   DYK
# 40703  일반 차량  2025   9월  0.0       Zhipao    내수  0.0  China Plants   DYK
#
#        공장판매량  현지판매량      지역명
# 0        0.0    0.0  아시아/태평양
# 1        0.0    0.0  아시아/태평양
# ...

# %%
df["차종"].unique()
# Out:
# array(['Accent (HC)', 'Bongo / Frontier', 'Bongo / Frontier (CKD)',
#        'Bongo / Frontier EV', 'Bus', 'Bus (CKD)', "Cee'd", "Cee'd CUV",
#        'Carens MPV', 'Carens MPV EV', 'Carnival / Sedona',
#        'Carnival / Sedona (CKD)', 'Cerato', 'EV2', 'EV3', 'EV4', 'EV5',
#        'EV6', 'EV9', 'Forte', 'K2', 'K3', 'K3 (CKD)', 'K4', 'K5 / Optima',
#        'K7, K8 / Cadenza', 'K9', 'KX1', 'Seltos / KX3', 'Sportage / KX5',
#        'KX7', 'Military', 'Military (CKD)', 'Mohave / Borrego',
#        'Morning / Picanto', 'New Carens', 'Niro', 'Niro EV', 'Niro Plus',
#        'Niro Plus EV', 'PV5', 'Pegas', 'Pride / Rio', 'Pride / Rio (FB)',
#        'Pride / Rio (SC)', 'Ray', 'Ray EV', 'Seltos', 'Seltos (CKD)',
#        'Sonet', 'Sorento', 'Sorento (CKD)', 'Soul', 'Soul (CKD)',
#        'Soul EV', 'Sportage', 'Stinger', 'Stonic', 'Syros', 'Tasman',
#        'Tasman (CKD)', 'Telluride', 'Tucson(NX4)', 'Zhipao'], dtype=object)

# %%
df["차종"].unique()
# Out:
# array([nan, 'Bongo / Frontier', 'Bongo / Frontier (CKD)', 'Seltos / KX3',
#        'Sportage / KX5', 'Mohave / Borrego', 'Morning / Picanto'],
#       dtype=object)
